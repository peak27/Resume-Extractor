# %% [markdown]
# # Install Required Libraries

# %%
#!pip install PyPDF2
#!pip install textract
#!pip install nltk
#!pip install wordcloud

# %% [markdown]
# # Import Libraries

# %%
#!pip install textract
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import PyPDF2 
import textract
import nltk
import re 
#nltk.download('all')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud

# %% [markdown]
# # Import PDF File & Convert To Text

# %%
#write a for-loop to open many files -- leave a comment if you'd #like to learn how
filename = 'Resumed.pdf' 
#open allows you to read the file
pdfFileObj = open(filename,'rb')
#The pdfReader variable is a readable object that will be parsed
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
#discerning the number of pages will allow us to parse through all #the pages
num_pages = pdfReader.numPages
count = 0
text = ""
#The while loop will read each page
while count < num_pages:
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()
#This if statement exists to check if the above library returned #words. It's done because PyPDF2 cannot read scanned files.
if text != "":
   text = text
#If the above returns as False, we run the OCR library textract to #convert scanned/image based PDF files into text
else:
   text = textract.process(fileurl, method='tesseract', language='eng')
# Now we have a text variable which contains all the text derived #from our PDF file. Type print(text) to see what it contains. It #likely contains a lot of spaces, possibly junk such as '\n' etc.
# Now, we will clean our text variable, and return it as a list of keywords.
print(text)
# Out:
#
# PRASHANT KARKI
#
# Computer Information Technology (CIT)
#
# ABOUT ME
#
# EDUCATION
#
# WORK EXPERIENCE
#
# CONTACTS
#
# TECHNICAL
#
# SKILLS
#
# PROJECTS
#
# ACHIEVEMENTS
#
# I am looking for a career in Data Science/
# Machine
# Learning
# , and hope to have a challenging opportunity
# that utilizes the strong skill
# -
# sets that I have developed
# over the years throughout my academic journey, here at
# MNSU.
#
# Basic
#
# und
# erstanding
#
# of
#
# Data
#
# Wareh
# ousing
#
# and
#
# Cloud
#
# Computing
# .
#
#
# UNDERGRADUATE
#
# MINNESOTA STATE UNIVERSITY, MANKATO
#
# 201
# 6
# -
#
# 20
# 20(May)
#
# Computer Information Technology
# Statistics (Minor)
#
#
#
# WEB DEVELOPER
#
# IT SOLUTIONS, MNSU
#
# MOBILE EXPERT
#
# CNC Machine Operator
#
#
# TARGET TECH, MARKETSOURCE
# -
#
# (1
#
# year +
# )
#
# OC Souvenir
#
#
# (
# 4
#
# months)
#
#
#
#
#
#
#
# Implemented skills like, Data cleaning, Data analysis and
# Data visualizations and came up
# with watershed problem solution.
#
#
# Tools like Tableau, Python, SAS, R, and more, were used.
#
# Operated CNC laser engraving and cutting machine. Set up
# machine parameter and proper fixture based on material type.
# Laser cut f
# iles using CAD, CorelDRAW, Illustrator, etc.
#
# 2019
#
# -
#
# 2019
#
# 2018
#
# -
#
# 2019
#
# 2018
#
# -
#
# Present
#
# Created multiple
# websites
#
# for MNSU departments and assisted
# campus units with content editing and website publishing.
#
# Activation of latest cellular devices for Verizon, AT&T, Sprint and
# more. Technical support for smartphones, computers and other
# electronic devices issues.
#
# (50
# 7)
# -
# 351
# -
# 6631
#
# Prashant.karki
# -
# 1@mnsu.edu
#
# Mankato, MN, 56001
#
# Python, R, SAS, MATLAB
#
# SQL,
# MongoDB, Apache Spark
#
# Tableau, Adobe Analytics, Power BI
#
# Data Analysis and Visualization
#
# Machine Learning
#
# Statistics and Modeling.
#
# Diagnosing/Troubleshooting
#
# Web Development.
#
# Software Development.
#
#
#
# linkedin.com/in/prashantkarki/
#
# (
# WIRELESS SALES ASSOCIATE)
#
# Predicti
# ng Obesity
#
# (
# Classification
# ) w/ SAS
#
#
#
# Performed Categorical Data Analysis on NHANES Dataset to predict the Obesity.
#
#
#
# Purposeful selection of variables in logistic regression. (Stepwise)
#
#
#
# Data Cleaning and Data Analysis tools: MATLAB, SAS
#
#
# Big Hits (Movie Rental Website) /w MVC 5 &
# SQL Server
#
#
#
#
#
# consist multiple databases for costumer, movies, etc. (INDIVIDUAL PROJECT)
#
#
#
# Complete e
# -
# commerce website.
#
#
#
# Served as Webmaster and Board member of ISA (International Student Association), MNSU.
#
#
# The Data Science Course 2019: Complete Data Science Bootcamp. (
# Certified
#
# Course)
#
#
# Machine Learning A
# -
# Z
#
# : Hands
# -
# On Python & R in Data Science. (Certified Course)
#
# Visualization of Sorting
# Algorithms w/ Unity and C# (Group Project)
#
#
#
#
#
# 3 (MNSU)
#
#
#
# (And Designer)
#
# SOFT
#
# SKILLS
#
# Problem Solving.
#
#
#
# Critical Thinking.
#
#
#
# Creative Thinking.
#
#
#
# Interpersonal Skills.
#
#
#
#
# github.com/peak27
#
#
# Statistical Calculator w/ Python and Tkinter
#
#
#
#
# C
# an calculate simple statistical calculation such as Mean, Median, Mode, Standard
# Deviation and Variance without any libraries
#
# used
#
# (Numpy, Math).
#
#
#
# Calculation such as
# Z
# -
# score, P
# -
# Values
#
# (with Z
# -
# score,Chi
# -
# Square, t
# -
# stat), Distributions and
# more
#
# (Including IEEE floating point converter)
# .
#
#
# Resume
#
# -
#
# Job Description Matcher System w/ Python
#
# (NL
# P
# )

# %% [markdown]
# # Cleaning Texts

# %%
#   Cleaning the text

corpus = ''
feedback = re.sub('[^a-zA-Z]', ' ', text) #   Keeping texts only
feedback = feedback.lower() #   All Lowercase
feedback = feedback.split() #   Creating list of review words
ps = PorterStemmer()
    # Remove stopwords & Stemming (Keeping root word only )
feedback = [ps.stem(word) for word in feedback if not word in set(stopwords.words('english'))]
feedback = ' '.join(feedback)
corpus = corpus + feedback
print(corpus)
# Out:
# prashant karki comput inform technolog cit educ work experi contact technic skill project achiev look career data scienc machin learn hope challeng opportun util strong skill set develop year throughout academ journey mnsu basic und erstand data wareh ous cloud comput undergradu minnesota state univers mankato may comput inform technolog statist minor web develop solut mnsu mobil expert cnc machin oper target tech marketsourc year oc souvenir month implement skill like data clean data analysi data visual came watersh problem solut tool like tableau python sa r use oper cnc laser engrav cut machin set machin paramet proper fixtur base materi type laser cut f ile use cad coreldraw illustr etc present creat multipl websit mnsu depart assist campu unit content edit websit publish activ latest cellular devic verizon sprint technic support smartphon comput electron devic issu prashant karki mnsu edu mankato mn python r sa matlab sql mongodb apach spark tableau adob analyt power bi data analysi visual machin learn statist model diagnos troubleshoot web develop softwar develop linkedin com prashantkarki wireless sale associ predicti ng obes classif w sa perform categor data analysi nhane dataset predict obes purpos select variabl logist regress stepwis data clean data analysi tool matlab sa big hit movi rental websit w mvc sql server consist multipl databas costum movi etc individu project complet e commerc websit serv webmast board member isa intern student associ mnsu data scienc cours complet data scienc bootcamp certifi cours machin learn z hand python r data scienc certifi cours visual sort algorithm w uniti c group project mnsu design soft skill problem solv critic think creativ think interperson skill github com peak statist calcul w python tkinter c calcul simpl statist calcul mean median mode standard deviat varianc without librari use numpi math calcul z score p valu z score chi squar stat distribut includ ieee float point convert resum job descript matcher system w python nl p

# %% [markdown]
# # Creating a WorcCloud

# %%
wordcloud = WordCloud(width=580, height=580, margin=0).generate(corpus)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# # Creating the list of words

# %%
#The word_tokenize() function will break our text phrases into #individual words
from nltk.tokenize import word_tokenize
tokens = word_tokenize(corpus)
#we'll create a new list which contains punctuation we wish to clean
punctuations = ['(',')',';',':','[',']',',']
#We initialize the stopwords variable which is a list of words like #"The", "I", "and", etc. that don't hold much value as keywords
stop_words = stopwords.words('english')
#We create a list comprehension which only returns a list of words #that are NOT IN stop_words and NOT IN punctuations.
keywords = [word for word in tokens if not word in stop_words and not word in punctuations]
print(keywords)
# Out:
# ['prashant', 'karki', 'comput', 'inform', 'technolog', 'cit', 'educ', 'work', 'experi', 'contact', 'technic', 'skill', 'project', 'achiev', 'look', 'career', 'data', 'scienc', 'machin', 'learn', 'hope', 'challeng', 'opportun', 'util', 'strong', 'skill', 'set', 'develop', 'year', 'throughout', 'academ', 'journey', 'mnsu', 'basic', 'und', 'erstand', 'data', 'wareh', 'ous', 'cloud', 'comput', 'undergradu', 'minnesota', 'state', 'univers', 'mankato', 'may', 'comput', 'inform', 'technolog', 'statist', 'minor', 'web', 'develop', 'solut', 'mnsu', 'mobil', 'expert', 'cnc', 'machin', 'oper', 'target', 'tech', 'marketsourc', 'year', 'oc', 'souvenir', 'month', 'implement', 'skill', 'like', 'data', 'clean', 'data', 'analysi', 'data', 'visual', 'came', 'watersh', 'problem', 'solut', 'tool', 'like', 'tableau', 'python', 'sa', 'r', 'use', 'oper', 'cnc', 'laser', 'engrav', 'cut', 'machin', 'set', 'machin', 'paramet', 'proper', 'fixtur', 'base', 'materi', 'type', 'laser', 'cut', 'f', 'ile', 'use', 'cad', 'coreldraw', 'illustr', 'etc', 'present', 'creat', 'multipl', 'websit', 'mnsu', 'depart', 'assist', 'campu', 'unit', 'content', 'edit', 'websit', 'publish', 'activ', 'latest', 'cellular', 'devic', 'verizon', 'sprint', 'technic', 'support', 'smartphon', 'comput', 'electron', 'devic', 'issu', 'prashant', 'karki', 'mnsu', 'edu', 'mankato', 'mn', 'python', 'r', 'sa', 'matlab', 'sql', 'mongodb', 'apach', 'spark', 'tableau', 'adob', 'analyt', 'power', 'bi', 'data', 'analysi', 'visual', 'machin', 'learn', 'statist', 'model', 'diagnos', 'troubleshoot', 'web', 'develop', 'softwar', 'develop', 'linkedin', 'com', 'prashantkarki', 'wireless', 'sale', 'associ', 'predicti', 'ng', 'obes', 'classif', 'w', 'sa', 'perform', 'categor', 'data', 'analysi', 'nhane', 'dataset', 'predict', 'obes', 'purpos', 'select', 'variabl', 'logist', 'regress', 'stepwis', 'data', 'clean', 'data', 'analysi', 'tool', 'matlab', 'sa', 'big', 'hit', 'movi', 'rental', 'websit', 'w', 'mvc', 'sql', 'server', 'consist', 'multipl', 'databas', 'costum', 'movi', 'etc', 'individu', 'project', 'complet', 'e', 'commerc', 'websit', 'serv', 'webmast', 'board', 'member', 'isa', 'intern', 'student', 'associ', 'mnsu', 'data', 'scienc', 'cours', 'complet', 'data', 'scienc', 'bootcamp', 'certifi', 'cours', 'machin', 'learn', 'z', 'hand', 'python', 'r', 'data', 'scienc', 'certifi', 'cours', 'visual', 'sort', 'algorithm', 'w', 'uniti', 'c', 'group', 'project', 'mnsu', 'design', 'soft', 'skill', 'problem', 'solv', 'critic', 'think', 'creativ', 'think', 'interperson', 'skill', 'github', 'com', 'peak', 'statist', 'calcul', 'w', 'python', 'tkinter', 'c', 'calcul', 'simpl', 'statist', 'calcul', 'mean', 'median', 'mode', 'standard', 'deviat', 'varianc', 'without', 'librari', 'use', 'numpi', 'math', 'calcul', 'z', 'score', 'p', 'valu', 'z', 'score', 'chi', 'squar', 'stat', 'distribut', 'includ', 'ieee', 'float', 'point', 'convert', 'resum', 'job', 'descript', 'matcher', 'system', 'w', 'python', 'nl', 'p']
