# %% [markdown]
# # Install Required Libraries

# %%
# !pip install PyPDF2
# !pip install textract
# !pip install nltk
# Out:
# Collecting PyPDF2
#   Downloading https://files.pythonhosted.org/packages/b4/01/68fcc0d43daf4c6bdbc6b33cc3f77bda531c86b174cac56ef0ffdb96faab/PyPDF2-1.26.0.tar.gz (77kB)
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py): started
#   Building wheel for PyPDF2 (setup.py): finished with status 'done'
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp37-none-any.whl size=61091 sha256=89694abab40ff42a016385e43383377c9c91e377a477868b29cedb4396f7b128
#   Stored in directory: C:\Users\gm3372pm\AppData\Local\pip\Cache\wheels\53\84\19\35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0
# Collecting textract
#   Downloading https://files.pythonhosted.org/packages/32/31/ef9451e6e48a1a57e337c5f20d4ef58c1a13d91560d2574c738b1320bb8d/textract-1.6.3-py3-none-any.whl
# Requirement already satisfied: six==1.12.0 in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from textract) (1.12.0)
# Requirement already satisfied: chardet==3.0.4 in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from textract) (3.0.4)
# Collecting extract-msg==0.23.1 (from textract)
#   Downloading https://files.pythonhosted.org/packages/a1/90/84485a914ed90adb5e87df17e626be04162fbba146dfecf34643659a4633/extract_msg-0.23.1-py2.py3-none-any.whl (45kB)
# Requirement already satisfied: beautifulsoup4==4.8.0 in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from textract) (4.8.0)
# Collecting pdfminer.six==20181108 (from textract)
#   Downloading https://files.pythonhosted.org/packages/8a/fd/6e8746e6965d1a7ea8e97253e3d79e625da5547e8f376f88de5d024bacb9/pdfminer.six-20181108-py2.py3-none-any.whl (5.6MB)
# Collecting SpeechRecognition==3.8.1 (from textract)
#   Downloading https://files.pythonhosted.org/packages/26/e1/7f5678cd94ec1234269d23756dbdaa4c8cfaed973412f88ae8adf7893a50/SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8MB)
# Collecting docx2txt==0.8 (from textract)
#   Downloading https://files.pythonhosted.org/packages/7d/7d/60ee3f2b16d9bfdfa72e8599470a2c1a5b759cb113c6fe1006be28359327/docx2txt-0.8.tar.gz
# Collecting EbookLib==0.17.1 (from textract)
#   Downloading https://files.pythonhosted.org/packages/00/38/7d6ab2e569a9165249619d73b7bc6be0e713a899a3bc2513814b6598a84c/EbookLib-0.17.1.tar.gz (111kB)
# Collecting argcomplete==1.10.0 (from textract)
#   Downloading https://files.pythonhosted.org/packages/4d/82/f44c9661e479207348a979b1f6f063625d11dc4ca6256af053719bbb0124/argcomplete-1.10.0-py2.py3-none-any.whl
# Requirement already satisfied: xlrd==1.2.0 in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from textract) (1.2.0)
# Collecting python-pptx==0.6.18 (from textract)
#   Downloading https://files.pythonhosted.org/packages/bf/86/eb979f7b0333ec769041aae36df8b9f1bd8bea5bbad44620663890dce561/python-pptx-0.6.18.tar.gz (8.9MB)
# Collecting tzlocal==1.5.1 (from extract-msg==0.23.1->textract)
#   Downloading https://files.pythonhosted.org/packages/cb/89/e3687d3ed99bc882793f82634e9824e62499fdfdc4b1ae39e211c5b05017/tzlocal-1.5.1.tar.gz
# Collecting imapclient==2.1.0 (from extract-msg==0.23.1->textract)
#   Downloading https://files.pythonhosted.org/packages/dc/39/e1c2c2c6e2356ab6ea81fcfc0a74b044b311d6a91a45300811d9a6077ef7/IMAPClient-2.1.0-py2.py3-none-any.whl (73kB)
# Requirement already satisfied: olefile==0.46 in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from extract-msg==0.23.1->textract) (0.46)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from beautifulsoup4==4.8.0->textract) (1.9.3)
# Collecting pycryptodome (from pdfminer.six==20181108->textract)
#   Downloading https://files.pythonhosted.org/packages/95/0d/db748eb8f68a56cc97e2d0bc62c26186999e7a074e166fc6186ce3449ebe/pycryptodome-3.9.7-cp37-cp37m-win_amd64.whl (14.1MB)
# Requirement already satisfied: sortedcontainers in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from pdfminer.six==20181108->textract) (2.1.0)
# Requirement already satisfied: lxml in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from EbookLib==0.17.1->textract) (4.4.1)
# Requirement already satisfied: Pillow>=3.3.2 in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from python-pptx==0.6.18->textract) (6.2.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from python-pptx==0.6.18->textract) (1.2.1)
# Requirement already satisfied: pytz in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from tzlocal==1.5.1->extract-msg==0.23.1->textract) (2019.3)
# Building wheels for collected packages: docx2txt, EbookLib, python-pptx, tzlocal
#   Building wheel for docx2txt (setup.py): started
#   Building wheel for docx2txt (setup.py): finished with status 'done'
#   Created wheel for docx2txt: filename=docx2txt-0.8-cp37-none-any.whl size=3969 sha256=3ea54c0757a878e5ad3011e38392931b5b8c38476428e968ec9a59d7a833fc6e
#   Stored in directory: C:\Users\gm3372pm\AppData\Local\pip\Cache\wheels\b2\1f\26\a051209bbb77fc6bcfae2bb7e01fa0ff941b82292ab084d596
#   Building wheel for EbookLib (setup.py): started
#   Building wheel for EbookLib (setup.py): finished with status 'done'
#   Created wheel for EbookLib: filename=EbookLib-0.17.1-cp37-none-any.whl size=38168 sha256=017bd05ffb19d294bf6289d92204e69d66b94b9764b35c4e2d6c4691cb91cfa5
#   Stored in directory: C:\Users\gm3372pm\AppData\Local\pip\Cache\wheels\84\11\01\951369cbbf8f96878786a1f4da68bd7ac19a5d945b38e03d54
#   Building wheel for python-pptx (setup.py): started
#   Building wheel for python-pptx (setup.py): finished with status 'done'
#   Created wheel for python-pptx: filename=python_pptx-0.6.18-cp37-none-any.whl size=275709 sha256=1eb5e31875ce6452faa1e30f95c0529b16d09ef7dd78d243f81732a9c442ba53
#   Stored in directory: C:\Users\gm3372pm\AppData\Local\pip\Cache\wheels\1f\1f\2c\29acca422b420a0b5210bd2cd7e9669804520d602d2462f20b
#   Building wheel for tzlocal (setup.py): started
#   Building wheel for tzlocal (setup.py): finished with status 'done'
#   Created wheel for tzlocal: filename=tzlocal-1.5.1-cp37-none-any.whl size=17548 sha256=6cb76240cd86bc9e78355210ac16d379931ad7f5836f90ffdc473c175ea90b8d
#   Stored in directory: C:\Users\gm3372pm\AppData\Local\pip\Cache\wheels\15\ae\df\a67bf1ed84e9bf230187d36d8dcfd30072bea0236cb059ed91
# Successfully built docx2txt EbookLib python-pptx tzlocal
# Installing collected packages: tzlocal, imapclient, extract-msg, pycryptodome, pdfminer.six, SpeechRecognition, docx2txt, EbookLib, argcomplete, python-pptx, textract
# Successfully installed EbookLib-0.17.1 SpeechRecognition-3.8.1 argcomplete-1.10.0 docx2txt-0.8 extract-msg-0.23.1 imapclient-2.1.0 pdfminer.six-20181108 pycryptodome-3.9.7 python-pptx-0.6.18 textract-1.6.3 tzlocal-1.5.1
# Requirement already satisfied: nltk in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (3.4.5)
# Requirement already satisfied: six in c:\users\gm3372pm\appdata\local\continuum\anaconda3\lib\site-packages (from nltk) (1.12.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import PyPDF2 
import textract
import nltk
#nltk.download('all')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
#write a for-loop to open many files -- leave a comment if you'd #like to learn how
filename = 'Resume.pdf' 
#open allows you to read the file
pdfFileObj = open(filename,'rb')
#The pdfReader variable is a readable object that will be parsed
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
#discerning the number of pages will allow us to parse through all #the pages
num_pages = pdfReader.numPages
count = 0
text = ""
#The while loop will read each page
while count < num_pages:
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()
#This if statement exists to check if the above library returned #words. It's done because PyPDF2 cannot read scanned files.
if text != "":
   text = text
#If the above returns as False, we run the OCR library textract to #convert scanned/image based PDF files into text
else:
   text = textract.process(fileurl, method='tesseract', language='eng')
# Now we have a text variable which contains all the text derived #from our PDF file. Type print(text) to see what it contains. It #likely contains a lot of spaces, possibly junk such as '\n' etc.
# Now, we will clean our text variable, and return it as a list of keywords.

# %%
print(text)
# Out:
#
# PRASHANT KARKI
#
# Computer Information Technology
#
# (CIT)
#
# ABOUT ME
#
# EDUCATION
#
# WORK EXPERIENCE
#
# CONTACTS
#
# TECHNICAL
#
# SKILLS
#
# PROJECTS
#
# ACHIEVEMENTS
#
# I am looking for a career in Dat
# a Science/Machine
# Learning field, and hope to have a challenging
# opportunity that utilizes the strong skill
# -
# sets that I have
# developed over the years throughout my academic
# journey, here at MNSU
# .
#
# Basic
#
# understanding
#
# of
#
# Data
#
# Warehousing,
#
# Big
#
# Data,
#
# Cloud
#
# Computing
#
# and
#
# Neural
#
# Networks
# .
#
#
# UNDERGRADUATE
#
# MINNESOTA STATE UNIVERSITY, MANKATO
#
# 201
# 6
#
# -
#
# 20
# 20
# (May)
#
#
# Computer Information Technology
# Statistics (Minor)
#
#
#
# WEB DEVELOPER
#
# IT SOLUTIONS, MNSU
#
#
# MOBILE EXPERT
#
# CNC Machine
# Operator
#
#
# CALL REPRESENTATIVE
#
# TARGET TECH, MARKETSOURCE
#
# -
#
# (1
#
# year
# )
#
# OC Souvenir
#
#
# (
# 4
#
# months)
#
# Ncell, Kathmandu, Nepal.
#
# (1 yr. 5 Months)
#
# MUDAC 2019 (MIDWEST UNDERGRADUATE DATA ANALYTICS COMPITETION)
#
#
# Represent
# ed
#
#
#
#
# Implement
# ed
#
# skills like, Data cleaning, Data
# analysis
#
# and Data visualizations
#
# and came up
# with watershed problem solution
# .
#
#
# Tools like Tableau, Python, SAS,
#
# R,
# and more, w
# ere
#
# used.
#
# Provided customer support &
# recommendation for cellphone
# plans, product and services. Understood customer requirements,
# business objectives and supported new technology
# implementation.
#
# Operated CNC laser engraving and cutting machine. Set up
# machine parameter and proper fixture bas
# ed on material type.
# Laser cut files using CAD,
#
# CorelDRAW,
# Illustrator, etc.
#
# 2014
#
# -
#
# 2016
#
# 201
# 9
#
# -
#
# 201
# 9
#
# 2018
#
# -
#
# 2019
#
# 201
# 8
#
# -
#
# Present
#
# Created multiple
# websites
#
# for MNSU departments and assisted
# campus units with content editing and website publishing.
#
# Activation of latest cellular devices for Verizon, AT&T, Sprint and
# more. Technical support for smartphones, computers and other
# electronic devices
# issues.
#
# (507)
# -
# 351
# -
# 6631
#
# Prashant.karki
# -
# 1@mnsu.edu
#
# Mankato
# ,
# MN, 56001
#
# Python,
#
# R,
#
# SAS, MATLAB
#
# SQL,
# MongoDB,
# Apache Spark
#
# Tableau, Adobe Analytics, Power BI
#
# Data
# Analysis
#
# and Visualization
#
# Machine Learning
#
# Statistics and
# Modeling.
#
# Diagnosing/Troubleshooting
#
# Web Development.
#
# Software Development.
#
#
#
# linkedin.com/in/prashantkarki/
#
# (
# WIRELESS SALES ASSOCIATE)
#
# (
# CONSULTANT)
#
# Categorical Data Analysis
#
# (
# Linear/Logistic Regression
# ) w/
# SAS
#
#
#
# Performed Categorical Data Analysis on NHANES Dataset to predict the Obesity.
#
#
#
# Purposeful selection of variables in logistic regression. (Stepwise)
#
#
#
# Data Cleaning and Data Analysis tools: MATLAB, SAS
#
#
# Big Hits (Movie
# Rental Website) /w MVC 5 & Entity Framework 6
#
#
#
#
#
# consist multiple databases for costumer, movies, etc. (INDIVIDUAL PROJECT)
#
#
#
# Serv
# ed
#
# as Webmaster and Board member of ISA (International Student Association), MNSU.
#
#
# The Data Science Course 2019: Complete Data Science Bootcamp. (
# Certified
#
# Course)
#
#
# Machine Learning A
# -
# Z
#
# : Hands
# -
# On
#
# Python & R in Data Science. (Certified Course)
#
# Visualization of Sorting Algorithms w/ Unity and C# (Group Project)
#
#
#
#
#
# 3 (MNSU)
#
#
#
# (And Designer)
#
# SOFT
#
# SKILLS
#
# Problem Solving.
#
#
#
# Critical Thinking.
#
#
#
# Creative Thinking.
#
#
#
# Interpersonal Skills.
#
#
#
#
# github.com/peak27

# %%
import re
text = re.sub(r'\d', '', text)
print(text)
# Out:
#
# PRASHANT KARKI
#
# Computer Information Technology
#
# (CIT)
#
# ABOUT ME
#
# EDUCATION
#
# WORK EXPERIENCE
#
# CONTACTS
#
# TECHNICAL
#
# SKILLS
#
# PROJECTS
#
# ACHIEVEMENTS
#
# I am looking for a career in Dat
# a Science/Machine
# Learning field, and hope to have a challenging
# opportunity that utilizes the strong skill
# -
# sets that I have
# developed over the years throughout my academic
# journey, here at MNSU
# .
#
# Basic
#
# understanding
#
# of
#
# Data
#
# Warehousing,
#
# Big
#
# Data,
#
# Cloud
#
# Computing
#
# and
#
# Neural
#
# Networks
# .
#
#
# UNDERGRADUATE
#
# MINNESOTA STATE UNIVERSITY, MANKATO
#
#
#
#
# -
#
#
#
# (May)
#
#
# Computer Information Technology
# Statistics (Minor)
#
#
#
# WEB DEVELOPER
#
# IT SOLUTIONS, MNSU
#
#
# MOBILE EXPERT
#
# CNC Machine
# Operator
#
#
# CALL REPRESENTATIVE
#
# TARGET TECH, MARKETSOURCE
#
# -
#
# (
#
# year
# )
#
# OC Souvenir
#
#
# (
#
#
# months)
#
# Ncell, Kathmandu, Nepal.
#
# ( yr.  Months)
#
# MUDAC  (MIDWEST UNDERGRADUATE DATA ANALYTICS COMPITETION)
#
#
# Represent
# ed
#
#
#
#
# Implement
# ed
#
# skills like, Data cleaning, Data
# analysis
#
# and Data visualizations
#
# and came up
# with watershed problem solution
# .
#
#
# Tools like Tableau, Python, SAS,
#
# R,
# and more, w
# ere
#
# used.
#
# Provided customer support &
# recommendation for cellphone
# plans, product and services. Understood customer requirements,
# business objectives and supported new technology
# implementation.
#
# Operated CNC laser engraving and cutting machine. Set up
# machine parameter and proper fixture bas
# ed on material type.
# Laser cut files using CAD,
#
# CorelDRAW,
# Illustrator, etc.
#
#
#
# -
#
#
#
#
#
#
# -
#
#
#
#
#
#
# -
#
#
#
#
#
#
# -
#
# Present
#
# Created multiple
# websites
#
# for MNSU departments and assisted
# campus units with content editing and website publishing.
#
# Activation of latest cellular devices for Verizon, AT&T, Sprint and
# more. Technical support for smartphones, computers and other
# electronic devices
# issues.
#
# ()
# -
#
# -
#
#
# Prashant.karki
# -
# @mnsu.edu
#
# Mankato
# ,
# MN,
#
# Python,
#
# R,
#
# SAS, MATLAB
#
# SQL,
# MongoDB,
# Apache Spark
#
# Tableau, Adobe Analytics, Power BI
#
# Data
# Analysis
#
# and Visualization
#
# Machine Learning
#
# Statistics and
# Modeling.
#
# Diagnosing/Troubleshooting
#
# Web Development.
#
# Software Development.
#
#
#
# linkedin.com/in/prashantkarki/
#
# (
# WIRELESS SALES ASSOCIATE)
#
# (
# CONSULTANT)
#
# Categorical Data Analysis
#
# (
# Linear/Logistic Regression
# ) w/
# SAS
#
#
#
# Performed Categorical Data Analysis on NHANES Dataset to predict the Obesity.
#
#
#
# Purposeful selection of variables in logistic regression. (Stepwise)
#
#
#
# Data Cleaning and Data Analysis tools: MATLAB, SAS
#
#
# Big Hits (Movie
# Rental Website) /w MVC  & Entity Framework
#
#
#
#
#
# consist multiple databases for costumer, movies, etc. (INDIVIDUAL PROJECT)
#
#
#
# Serv
# ed
#
# as Webmaster and Board member of ISA (International Student Association), MNSU.
#
#
# The Data Science Course : Complete Data Science Bootcamp. (
# Certified
#
# Course)
#
#
# Machine Learning A
# -
# Z
#
# : Hands
# -
# On
#
# Python & R in Data Science. (Certified Course)
#
# Visualization of Sorting Algorithms w/ Unity and C# (Group Project)
#
#
#
#
#
#  (MNSU)
#
#
#
# (And Designer)
#
# SOFT
#
# SKILLS
#
# Problem Solving.
#
#
#
# Critical Thinking.
#
#
#
# Creative Thinking.
#
#
#
# Interpersonal Skills.
#
#
#
#
# github.com/peak

# %%
#The word_tokenize() function will break our text phrases into #individual words
tokens = word_tokenize(text)
#we'll create a new list which contains punctuation we wish to clean
punctuations = ['(',')',';',':','[',']',',']
#We initialize the stopwords variable which is a list of words like #"The", "I", "and", etc. that don't hold much value as keywords
stop_words = stopwords.words('english')
#We create a list comprehension which only returns a list of words #that are NOT IN stop_words and NOT IN punctuations.
keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
print(keywords)
# Out:
# ['PRASHANT', 'KARKI', 'Computer', 'Information', 'Technology', 'CIT', 'ABOUT', 'ME', 'EDUCATION', 'WORK', 'EXPERIENCE', 'CONTACTS', 'TECHNICAL', 'SKILLS', 'PROJECTS', 'ACHIEVEMENTS', 'I', 'looking', 'career', 'Dat', 'Science/Machine', 'Learning', 'field', 'hope', 'challenging', 'opportunity', 'utilizes', 'strong', 'skill', '-', 'sets', 'I', 'developed', 'years', 'throughout', 'academic', 'journey', 'MNSU', '.', 'Basic', 'understanding', 'Data', 'Warehousing', 'Big', 'Data', 'Cloud', 'Computing', 'Neural', 'Networks', '.', 'UNDERGRADUATE', 'MINNESOTA', 'STATE', 'UNIVERSITY', 'MANKATO', '-', 'May', 'Computer', 'Information', 'Technology', 'Statistics', 'Minor', 'WEB', 'DEVELOPER', 'IT', 'SOLUTIONS', 'MNSU', 'MOBILE', 'EXPERT', 'CNC', 'Machine', 'Operator', 'CALL', 'REPRESENTATIVE', 'TARGET', 'TECH', 'MARKETSOURCE', '-', 'year', 'OC', 'Souvenir', 'months', 'Ncell', 'Kathmandu', 'Nepal', '.', 'yr', '.', 'Months', 'MUDAC', 'MIDWEST', 'UNDERGRADUATE', 'DATA', 'ANALYTICS', 'COMPITETION', 'Represent', 'ed', 'Implement', 'ed', 'skills', 'like', 'Data', 'cleaning', 'Data', 'analysis', 'Data', 'visualizations', 'came', 'watershed', 'problem', 'solution', '.', 'Tools', 'like', 'Tableau', 'Python', 'SAS', 'R', 'w', 'ere', 'used', '.', 'Provided', 'customer', 'support', '&', 'recommendation', 'cellphone', 'plans', 'product', 'services', '.', 'Understood', 'customer', 'requirements', 'business', 'objectives', 'supported', 'new', 'technology', 'implementation', '.', 'Operated', 'CNC', 'laser', 'engraving', 'cutting', 'machine', '.', 'Set', 'machine', 'parameter', 'proper', 'fixture', 'bas', 'ed', 'material', 'type', '.', 'Laser', 'cut', 'files', 'using', 'CAD', 'CorelDRAW', 'Illustrator', 'etc', '.', '-', '-', '-', '-', 'Present', 'Created', 'multiple', 'websites', 'MNSU', 'departments', 'assisted', 'campus', 'units', 'content', 'editing', 'website', 'publishing', '.', 'Activation', 'latest', 'cellular', 'devices', 'Verizon', 'AT', '&', 'T', 'Sprint', '.', 'Technical', 'support', 'smartphones', 'computers', 'electronic', 'devices', 'issues', '.', '-', '-', 'Prashant.karki', '-', '@', 'mnsu.edu', 'Mankato', 'MN', 'Python', 'R', 'SAS', 'MATLAB', 'SQL', 'MongoDB', 'Apache', 'Spark', 'Tableau', 'Adobe', 'Analytics', 'Power', 'BI', 'Data', 'Analysis', 'Visualization', 'Machine', 'Learning', 'Statistics', 'Modeling', '.', 'Diagnosing/Troubleshooting', 'Web', 'Development', '.', 'Software', 'Development', '.', 'linkedin.com/in/prashantkarki/', 'WIRELESS', 'SALES', 'ASSOCIATE', 'CONSULTANT', 'Categorical', 'Data', 'Analysis', 'Linear/Logistic', 'Regression', 'w/', 'SAS', 'Performed', 'Categorical', 'Data', 'Analysis', 'NHANES', 'Dataset', 'predict', 'Obesity', '.', 'Purposeful', 'selection', 'variables', 'logistic', 'regression', '.', 'Stepwise', 'Data', 'Cleaning', 'Data', 'Analysis', 'tools', 'MATLAB', 'SAS', 'Big', 'Hits', 'Movie', 'Rental', 'Website', '/w', 'MVC', '&', 'Entity', 'Framework', 'consist', 'multiple', 'databases', 'costumer', 'movies', 'etc', '.', 'INDIVIDUAL', 'PROJECT', 'Serv', 'ed', 'Webmaster', 'Board', 'member', 'ISA', 'International', 'Student', 'Association', 'MNSU', '.', 'The', 'Data', 'Science', 'Course', 'Complete', 'Data', 'Science', 'Bootcamp', '.', 'Certified', 'Course', 'Machine', 'Learning', 'A', '-', 'Z', 'Hands', '-', 'On', 'Python', '&', 'R', 'Data', 'Science', '.', 'Certified', 'Course', 'Visualization', 'Sorting', 'Algorithms', 'w/', 'Unity', 'C', '#', 'Group', 'Project', 'MNSU', 'And', 'Designer', 'SOFT', 'SKILLS', 'Problem', 'Solving', '.', 'Critical', 'Thinking', '.', 'Creative', 'Thinking', '.', 'Interpersonal', 'Skills', '.', 'github.com/peak']

# %%
text = text.lower()

# %%
#!pip install wordcloud
from wordcloud import WordCloud
wordcloud = WordCloud(width=480, height=480, margin=0).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
